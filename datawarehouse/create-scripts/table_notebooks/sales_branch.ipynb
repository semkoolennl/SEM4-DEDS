# %%
import pandas as pd
from utils import *
# Out:
# C:\Users\joren\AppData\Local\Temp\ipykernel_21880\1421855552.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
# -- SALES_BRANCH doeltabel --

# SALES_BRANCH_CODE
# SALES_BRANCH_REGION
# SALES_BRANCH_CITY
# SALES_BRANCH_POSTAL_CODE
# SALES_BRANCH_ADDRESS1
# SALES_BRANCH_ADDRESS2
# SALES_STAFF_SALES_STAFF_CODE
# SALES_STAFF_MANAGER_CODE
# SALES_STAFF_FIRST_NAME
# SALES_STAFF_LAST_NAME
# SALES_STAFF_POSITION_EN
# SALES_STAFF_WORK_PHONE
# SALES_STAFF_FAX
# SALES_STAFF_EXTENSION
# SALES_STAFF_EMAIL
# SALES_STAFF_DATE_HIRED
# COUNTRY_COUNTRY_CODE
# COUNTRY_COUNTRY
# COUNTRY_LANGUAGE
# COUNTRY_CURRENCY_NAME

# %%
go_sales = load_db('../source/go_sales.sqlite')

# %%
sales_branch = load_table(go_sales, 'SALES_BRANCH').add_prefix('SALES_BRANCH_')
sales_staff = load_table(go_sales, 'SALES_STAFF').add_prefix('SALES_STAFF_')
sales_country = load_table(go_sales, 'COUNTRY').add_prefix('COUNTRY_')

# %%
# JOIN
# sales_branch.sales_branch_code = sales_staff_sales_branch_code
# sales_branch.country_code = country_country_code
# sales_staff.manager_code = sales_staff.sales_staff_code

result = sales_branch.merge(sales_staff, left_on='SALES_BRANCH_SALES_BRANCH_CODE', right_on='SALES_STAFF_SALES_BRANCH_CODE', how='inner')
result = result.merge(sales_country, left_on='SALES_BRANCH_COUNTRY_CODE', right_on='COUNTRY_COUNTRY_CODE', how='left')

result
# Out:
#     SALES_BRANCH_SALES_BRANCH_CODE SALES_BRANCH_ADDRESS1  \
# 0                               13        Schwabentor 35
# 1                               13        Schwabentor 35
# 2                               13        Schwabentor 35
# 3                               13        Schwabentor 35
# 4                               14      Leopoldstraße 36
# ..                             ...                   ...
# 97                               9   Singelgravenplein 4
# 98                               9   Singelgravenplein 4
# 99                               9   Singelgravenplein 4
# 100                              9   Singelgravenplein 4
# 101                              9   Singelgravenplein 4
#
#     SALES_BRANCH_ADDRESS2 SALES_BRANCH_CITY SALES_BRANCH_REGION  \
# 0                    None           Hamburg                None
# 1                    None           Hamburg                None
# 2                    None           Hamburg                None
# 3                    None           Hamburg                None
# 4                    None           München                None
# ..                    ...               ...                 ...
# 97          4e verdieping         Amsterdam       Noord-Holland
# 98          4e verdieping         Amsterdam       Noord-Holland
# 99          4e verdieping         Amsterdam       Noord-Holland
# 100         4e verdieping         Amsterdam       Noord-Holland
# 101         4e verdieping         Amsterdam       Noord-Holland
#
#     SALES_BRANCH_POSTAL_ZONE SALES_BRANCH_COUNTRY_CODE  \
# 0                    D-22529                         2
# 1                    D-22529                         2
# 2                    D-22529                         2
# 3                    D-22529                         2
# 4                    D-81241                         2
# ..                       ...                       ...
# 97                   1233 BW                         7
# 98                   1233 BW                         7
# 99                   1233 BW                         7
# 100                  1233 BW                         7
# 101                  1233 BW                         7
#
#     SALES_STAFF_SALES_STAFF_CODE SALES_STAFF_FIRST_NAME SALES_STAFF_LAST_NAME  \
# 0                             12                Elsbeth             Wiesinger
# 1                             13                   Else                Mörike
# 2                             14                  Frank                 Fuchs
# 3                             15                 Gunter                 Erler
# 4                             16                  Björn               Winkler
# ..                           ...                    ...                   ...
# 97                            22                Belinda      Jansen-Velasquez
# 98                            23                  Ellen               Shapiro
# 99                            24                    Jan             Haverkamp
# 100                           25                   Kick               Kalkman
# 101                           26                  Maria              Laponder
#
#      ... SALES_STAFF_WORK_PHONE SALES_STAFF_EXTENSION      SALES_STAFF_FAX  \
# 0    ...      +(49) 40 663 1990                  1818    +(49) 40 663 4571
# 1    ...      +(49) 40 663 1990                  1865    +(49) 40 663 4571
# 2    ...      +(49) 40 663 1990                  1847    +(49) 40 663 4571
# 3    ...      +(49) 40 663 1990                  1823    +(49) 40 663 4571
# 4    ...      +(49) 89 882 3456                   224    +(49) 89 882 3455
# ..   ...                    ...                   ...                  ...
# 97   ...    +31 (0)20 692 93 94                   187  +31 (0)20 692 93 06
# 98   ...    +31 (0)20 692 93 94                   179  +31 (0)20 692 93 06
# 99   ...    +31 (0)20 692 93 94                   163  +31 (0)20 692 93 06
# 100  ...    +31 (0)20 692 93 94                   197  +31 (0)20 692 93 06
# 101  ...    +31 (0)20 692 93 94                   144  +31 (0)20 692 93 06
#
#           SALES_STAFF_EMAIL SALES_STAFF_DATE_HIRED  \
# 0    EWiesinger@grtd123.com              27-2-2013
# 1       EMorike@grtd123.com               2-6-2015
# 2        FFuchs@grtd123.com              12-1-2013
# 3        GErler@grtd123.com               5-3-2014
# 4      BWinkler@grtd123.com               3-7-2012
# ..                      ...                    ...
# 97   BVelasquez@grtd123.com              12-2-2015
# 98     EShapiro@grtd123.com              15-1-2015
# 99   JHaverkamp@grtd123.com              18-7-2014
# 100    KKalkman@grtd123.com               6-9-2011
# 101   MLaponder@grtd123.com             10-10-2011
#
#     SALES_STAFF_SALES_BRANCH_CODE COUNTRY_COUNTRY_CODE COUNTRY_COUNTRY  \
# 0                              13                    2         Germany
# 1                              13                    2         Germany
# 2                              13                    2         Germany
# 3                              13                    2         Germany
# 4                              14                    2         Germany
# ..                            ...                  ...             ...
# 97                              9                    7     Netherlands
# 98                              9                    7     Netherlands
# 99                              9                    7     Netherlands
# 100                             9                    7     Netherlands
# 101                             9                    7     Netherlands
#
#     COUNTRY_LANGUAGE COUNTRY_CURRENCY_NAME
# 0                 EN                 marks
# 1                 EN                 marks
# 2                 EN                 marks
# 3                 EN                 marks
# 4                 EN                 marks
# ..               ...                   ...
# 97                EN              guilders
# 98                EN              guilders
# 99                EN              guilders
# 100               EN              guilders
# 101               EN              guilders
#
# [102 rows x 21 columns]

# %%
# Remove redundant columns
result = result.drop(columns=['SALES_BRANCH_COUNTRY_CODE', 'SALES_STAFF_SALES_BRANCH_CODE'])

# Rename foreign key columns
result = result.rename(columns={
    'SALES_BRANCH_SALES_BRANCH_CODE': 'SALES_BRANCH_CODE',
    'SALES_STAFF_SALES_STAFF_CODE': 'SALES_STAFF_CODE',
})

result
# Out:
#     SALES_BRANCH_CODE SALES_BRANCH_ADDRESS1 SALES_BRANCH_ADDRESS2  \
# 0                  13        Schwabentor 35                  None
# 1                  13        Schwabentor 35                  None
# 2                  13        Schwabentor 35                  None
# 3                  13        Schwabentor 35                  None
# 4                  14      Leopoldstraße 36                  None
# ..                ...                   ...                   ...
# 97                  9   Singelgravenplein 4         4e verdieping
# 98                  9   Singelgravenplein 4         4e verdieping
# 99                  9   Singelgravenplein 4         4e verdieping
# 100                 9   Singelgravenplein 4         4e verdieping
# 101                 9   Singelgravenplein 4         4e verdieping
#
#     SALES_BRANCH_CITY SALES_BRANCH_REGION SALES_BRANCH_POSTAL_ZONE  \
# 0             Hamburg                None                  D-22529
# 1             Hamburg                None                  D-22529
# 2             Hamburg                None                  D-22529
# 3             Hamburg                None                  D-22529
# 4             München                None                  D-81241
# ..                ...                 ...                      ...
# 97          Amsterdam       Noord-Holland                  1233 BW
# 98          Amsterdam       Noord-Holland                  1233 BW
# 99          Amsterdam       Noord-Holland                  1233 BW
# 100         Amsterdam       Noord-Holland                  1233 BW
# 101         Amsterdam       Noord-Holland                  1233 BW
#
#     SALES_STAFF_CODE SALES_STAFF_FIRST_NAME SALES_STAFF_LAST_NAME  \
# 0                 12                Elsbeth             Wiesinger
# 1                 13                   Else                Mörike
# 2                 14                  Frank                 Fuchs
# 3                 15                 Gunter                 Erler
# 4                 16                  Björn               Winkler
# ..               ...                    ...                   ...
# 97                22                Belinda      Jansen-Velasquez
# 98                23                  Ellen               Shapiro
# 99                24                    Jan             Haverkamp
# 100               25                   Kick               Kalkman
# 101               26                  Maria              Laponder
#
#           SALES_STAFF_POSITION_EN SALES_STAFF_WORK_PHONE  \
# 0    Level 2 Sales Representative      +(49) 40 663 1990
# 1                Regional Manager      +(49) 40 663 1990
# 2                  Branch Manager      +(49) 40 663 1990
# 3    Level 2 Sales Representative      +(49) 40 663 1990
# 4    Level 3 Sales Representative      +(49) 89 882 3456
# ..                            ...                    ...
# 97   Level 1 Sales Representative    +31 (0)20 692 93 94
# 98   Level 2 Sales Representative    +31 (0)20 692 93 94
# 99   Level 2 Sales Representative    +31 (0)20 692 93 94
# 100                Branch Manager    +31 (0)20 692 93 94
# 101  Level 3 Sales Representative    +31 (0)20 692 93 94
#
#     SALES_STAFF_EXTENSION      SALES_STAFF_FAX       SALES_STAFF_EMAIL  \
# 0                    1818    +(49) 40 663 4571  EWiesinger@grtd123.com
# 1                    1865    +(49) 40 663 4571     EMorike@grtd123.com
# 2                    1847    +(49) 40 663 4571      FFuchs@grtd123.com
# 3                    1823    +(49) 40 663 4571      GErler@grtd123.com
# 4                     224    +(49) 89 882 3455    BWinkler@grtd123.com
# ..                    ...                  ...                     ...
# 97                    187  +31 (0)20 692 93 06  BVelasquez@grtd123.com
# 98                    179  +31 (0)20 692 93 06    EShapiro@grtd123.com
# 99                    163  +31 (0)20 692 93 06  JHaverkamp@grtd123.com
# 100                   197  +31 (0)20 692 93 06    KKalkman@grtd123.com
# 101                   144  +31 (0)20 692 93 06   MLaponder@grtd123.com
#
#     SALES_STAFF_DATE_HIRED COUNTRY_COUNTRY_CODE COUNTRY_COUNTRY  \
# 0                27-2-2013                    2         Germany
# 1                 2-6-2015                    2         Germany
# 2                12-1-2013                    2         Germany
# 3                 5-3-2014                    2         Germany
# 4                 3-7-2012                    2         Germany
# ..                     ...                  ...             ...
# 97               12-2-2015                    7     Netherlands
# 98               15-1-2015                    7     Netherlands
# 99               18-7-2014                    7     Netherlands
# 100               6-9-2011                    7     Netherlands
# 101             10-10-2011                    7     Netherlands
#
#     COUNTRY_LANGUAGE COUNTRY_CURRENCY_NAME
# 0                 EN                 marks
# 1                 EN                 marks
# 2                 EN                 marks
# 3                 EN                 marks
# 4                 EN                 marks
# ..               ...                   ...
# 97                EN              guilders
# 98                EN              guilders
# 99                EN              guilders
# 100               EN              guilders
# 101               EN              guilders
#
# [102 rows x 19 columns]
