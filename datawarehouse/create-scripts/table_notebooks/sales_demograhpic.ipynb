# %%
import pandas as pd
from utils import *
# Out:
# /tmp/ipykernel_169592/1421855552.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
# ResultTable overview - Sales_demographic 

# SALES_DEMOGRAPHIC_DEMOGRAPHIC_CODE
# SALES_DEMOGRAPHIC_SALES_PERCENT
# RETAILER_HEADQUARTERS_RETAILER_CODEMR
# RETAILER_HEADQUARTERS_RETAILER_NAME
# RETAILER_HEADQUARTERS_ADDRESS1
# RETAILER_HEADQUARTERS_ADDRESS2
# RETAILER_HEADQUARTERS_CITY
# RETAILER_HEADQUARTERS_REGION
# RETAILER_HEADQUARTERS_POSTAL_ZONE
# RETAILER_HEADQUARTERS_PHONE
# RETAILER_HEADQUARTERS_FAX
# RETAILER_SEGMENT_SEGMENT_CODE
# RETAILER_SEGMENT_LANGUAGE
# RETAILER_SEGMENT_SEGMENT_NAME
# RETAILER_SEGMENT_SEGMENT_DESCRIPTION
# AGE_GROUP_AGE_GROUP_CODE
# AGE_GROUP_UPPER_AGE
# AGE_GROUP_LOWER_AGE
# RETAILER_COUNTRY_COUNTRY_CODE
# RETAILER_COUNTRY_COUNTRY_EN
# RETAILER_COUNTRY_FLAG_IMAGE
# SALES_TERRITORY_SALES_TERRITORY_CODE
# SALES_TERRITORY_TERRITORY_NAME_EN

# %%
go_crm = load_db('../source/go_crm.sqlite')

# %%
retailer_heaquarters = load_table(go_crm, 'retailer_headquarters').add_prefix('RETAILER_HEADQUARTERS_')
retailer_site = load_table(go_crm, 'retailer_site').add_prefix('RETAILER_SITE_')
retailer_segment = load_table(go_crm, 'retailer_segment').add_prefix('RETAILER_SEGMENT_')
retailer_country = load_table(go_crm, 'country').add_prefix('RETAILER_COUNTRY_')
sales_demographic = load_table(go_crm, 'sales_demographic').add_prefix('SALES_DEMOGRAPHIC_')
sales_territory = load_table(go_crm, 'sales_territory').add_prefix('SALES_TERRITORY_')
age_group = load_table(go_crm, 'age_group').add_prefix('AGE_GROUP_')


result = pd.merge(
    sales_demographic, retailer_heaquarters, left_on="SALES_DEMOGRAPHIC_RETAILER_CODEMR", right_on="RETAILER_HEADQUARTERS_RETAILER_CODEMR"
    ).drop(columns='SALES_DEMOGRAPHIC_RETAILER_CODEMR')

result = pd.merge(
    result, retailer_segment, left_on='RETAILER_HEADQUARTERS_SEGMENT_CODE', right_on='RETAILER_SEGMENT_SEGMENT_CODE'
    ).drop(columns='RETAILER_HEADQUARTERS_SEGMENT_CODE')

result = pd.merge(
    result, age_group, left_on="SALES_DEMOGRAPHIC_AGE_GROUP_CODE", right_on="AGE_GROUP_AGE_GROUP_CODE"
    ).drop(columns='SALES_DEMOGRAPHIC_AGE_GROUP_CODE')

result = pd.merge(
    result, retailer_country, left_on='RETAILER_HEADQUARTERS_COUNTRY_CODE', right_on='RETAILER_COUNTRY_COUNTRY_CODE'
    ).drop(columns='RETAILER_HEADQUARTERS_COUNTRY_CODE')

result = pd.merge(
    result, sales_territory, left_on='RETAILER_COUNTRY_SALES_TERRITORY_CODE', right_on='SALES_TERRITORY_SALES_TERRITORY_CODE'
    ).drop(columns='RETAILER_COUNTRY_SALES_TERRITORY_CODE')

# %%
result
# Out:
#      SALES_DEMOGRAPHIC_DEMOGRAPHIC_CODE SALES_DEMOGRAPHIC_SALES_PERCENT  \
# 0                                     1                              52
# 1                                    10                              16
# 2                                   100                              11
# 3                                  1000                               6
# 4                                  1001                               9
# ...                                 ...                             ...
# 2479                                995                               4
# 2480                                996                               5
# 2481                                997                               3
# 2482                                998                              32
# 2483                                999                              37
#
#      RETAILER_HEADQUARTERS_RETAILER_CODEMR  \
# 0                                        1
# 1                                        2
# 2                                       17
# 3                                      164
# 4                                      164
# ...                                    ...
# 2479                                   143
# 2480                                   143
# 2481                                   143
# 2482                                   164
# 2483                                   164
#
#      RETAILER_HEADQUARTERS_RETAILER_NAME RETAILER_HEADQUARTERS_ADDRESS1  \
# 0                            Rock Steady                45, rue Atwater
# 1                           Ultra Sports                 2425, rue Peel
# 2                 Andes Camping Supplies                  11 Moose Road
# 3             Terra Nova Camping Rentals        10442 N. Mulberry Place
# 4             Terra Nova Camping Rentals        10442 N. Mulberry Place
# ...                                  ...                            ...
# 2479                       Le Montagnard             21, place des Prés
# 2480                       Le Montagnard             21, place des Prés
# 2481                       Le Montagnard             21, place des Prés
# 2482          Terra Nova Camping Rentals        10442 N. Mulberry Place
# 2483          Terra Nova Camping Rentals        10442 N. Mulberry Place
#
#      RETAILER_HEADQUARTERS_ADDRESS2 RETAILER_HEADQUARTERS_CITY  \
# 0                              None                   Montréal
# 1                              None                   Montréal
# 2                              None                      Banff
# 3                              None                     Tuscon
# 4                              None                     Tuscon
# ...                             ...                        ...
# 2479                           None                    Valence
# 2480                           None                    Valence
# 2481                           None                    Valence
# 2482                           None                     Tuscon
# 2483                           None                     Tuscon
#
#      RETAILER_HEADQUARTERS_REGION RETAILER_HEADQUARTERS_POSTAL_ZONE  \
# 0                          Québec                           H2T 9K8
# 1                          Québec                           H4G 3T4
# 2                         Alberta                           T4V 1D4
# 3                         Arizona                             85711
# 4                         Arizona                             85711
# ...                           ...                               ...
# 2479                         None                           F-26000
# 2480                         None                           F-26000
# 2481                         None                           F-26000
# 2482                      Arizona                             85711
# 2483                      Arizona                             85711
#
#      RETAILER_HEADQUARTERS_PHONE  ... RETAILER_SEGMENT_SEGMENT_NAME  \
# 0               1 (514) 747-4481  ...                 Outdoors Shop
# 1               1 (514) 746-1273  ...      Sports Store - Exclusive
# 2               1 (403) 762-8672  ...                 Outdoors Shop
# 3               1 (520) 575-6899  ...        Equipment Rental Store
# 4               1 (520) 575-6899  ...        Equipment Rental Store
# ...                          ...  ...                           ...
# 2479           +33 4 65 02 16 23  ...        Equipment Rental Store
# 2480           +33 4 65 02 16 23  ...        Equipment Rental Store
# 2481           +33 4 65 02 16 23  ...        Equipment Rental Store
# 2482            1 (520) 575-6899  ...        Equipment Rental Store
# 2483            1 (520) 575-6899  ...        Equipment Rental Store
#
#                    RETAILER_SEGMENT_SEGMENT_DESCRIPTION  \
# 0     Primarily offers camping supplies, hiking equi...
# 1     Primarily offers a wide range of sporting good...
# 2     Primarily offers camping supplies, hiking equi...
# 3     Offers various sports and outdoors equipment f...
# 4     Offers various sports and outdoors equipment f...
# ...                                                 ...
# 2479  Offers various sports and outdoors equipment f...
# 2480  Offers various sports and outdoors equipment f...
# 2481  Offers various sports and outdoors equipment f...
# 2482  Offers various sports and outdoors equipment f...
# 2483  Offers various sports and outdoors equipment f...
#
#      AGE_GROUP_AGE_GROUP_CODE AGE_GROUP_UPPER_AGE AGE_GROUP_LOWER_AGE  \
# 0                           1                  20                   0
# 1                           4                  50                  41
# 2                           4                  50                  41
# 3                           3                  40                  31
# 4                           4                  50                  41
# ...                       ...                 ...                 ...
# 2479                        4                  50                  41
# 2480                        5                  60                  51
# 2481                        6                  70                  61
# 2482                        1                  20                   0
# 2483                        2                  30                  21
#
#      RETAILER_COUNTRY_COUNTRY_CODE RETAILER_COUNTRY_COUNTRY_EN  \
# 0                                4                      Canada
# 1                                4                      Canada
# 2                                4                      Canada
# 3                                3               United States
# 4                                3               United States
# ...                            ...                         ...
# 2479                             1                      France
# 2480                             1                      France
# 2481                             1                      France
# 2482                             3               United States
# 2483                             3               United States
#
#      RETAILER_COUNTRY_FLAG_IMAGE SALES_TERRITORY_SALES_TERRITORY_CODE  \
# 0                            F04                                    1
# 1                            F04                                    1
# 2                            F04                                    1
# 3                            F03                                    1
# 4                            F03                                    1
# ...                          ...                                  ...
# 2479                         F01                                    6
# 2480                         F01                                    6
# 2481                         F01                                    6
# 2482                         F03                                    1
# 2483                         F03                                    1
#
#      SALES_TERRITORY_TERRITORY_NAME_EN
# 0                             Americas
# 1                             Americas
# 2                             Americas
# 3                             Americas
# 4                             Americas
# ...                                ...
# 2479                    Central Europe
# 2480                    Central Europe
# 2481                    Central Europe
# 2482                          Americas
# 2483                          Americas
#
# [2484 rows x 23 columns]
